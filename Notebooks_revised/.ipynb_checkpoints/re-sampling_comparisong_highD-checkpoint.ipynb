# %%
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt
import torch
import sys
# setting path 
sys.path.append('../')
from NeuralNetworks.NNs import FCFF_3L
from PointSampling.Ball import data_gen_ball
from visualization.plots_disc import plot_2d_proj_disc
from visualization.disc_training import plot_2d_proj_w
from Hamiltonians.Eikonal_LxF import Eikonal_sq_LF_multiD 
from Training.training_finite_sum import train_finite_sum
from error_test.cube_error import FD_loss
from error_test.disc_error import error_ball

dim = 5

radii = [3., 0.]
domain = data_gen_ball(radii, dim)

#Right-hand-side of the PDE
def f(X): return 1

#Boundary condition
def g(X): return 0

delta_list = [.7, .5, .2, .1, .05]
alpha_list = [2., 2., 2., 2., 2.]
rounds = len(delta_list)
training_params = {
    'numerical_scheme': Eikonal_sq_LF_multiD,
    
    'f': f, 
    'g': g, 
    'c': None,
    
    'beta': 0., ## parameter for the +u_i term 
    
    'lambda': 1. #weight parameter for the boundary loss
}

# Test data
x_grid = torch.linspace(-max(radii), max(radii), int(21))
print('delta_test = ', x_grid[1]-x_grid[0] )
X = torch.meshgrid([x_grid]*dim)
data_square = torch.cat([X[i].unsqueeze(-1) for i in range(dim)], dim = -1).reshape([-1, dim])
test_data = data_square[data_square.norm(dim = -1) < max(radii)]
print('Number of test points =', test_data.shape[0])

n_experiments = 10
# Out:
# delta_test =  tensor(0.3000)
# Number of test points = 526979
# C:\Users\usuario\anaconda3\envs\FD_PINNs\Lib\site-packages\torch\functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\b\abs_e1nmgx0bk6\croot\pytorch-select_1725478824526\work\aten\src\ATen\native\TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# # Fixed collocation points I

# %%
MSE_history1 = torch.zeros([n_experiments, rounds])
L_inf_error_history1 = torch.zeros([n_experiments, rounds]) 

training_error_history1 = torch.zeros([n_experiments, rounds])
test_error_history1 = torch.zeros([n_experiments, rounds])

training_error_history1_max = torch.zeros([n_experiments, rounds])
test_error_history1_max = torch.zeros([n_experiments, rounds])


for j in range(n_experiments):
    # We initialise the NN
    NN1 = FCFF_3L([dim,30,30])
    training_params['optimizer'] = optim.SGD(NN1.parameters(), lr = .01, momentum = .2)
    
    ## Here we sample the collocation points and the boundary points.
    training_data_int = domain.rand_int_points(0., 200)
    training_data_bound = domain.rand_bound_points(40)
    
    training_params['epochs'] = 500
    training_params['batch_size'] = 50

    
    for i in range(rounds):
    
        training_params['alpha'] = alpha_list[i]
        training_params['delta'] = delta_list[i]
        
        total_loss, PDE_loss, boundary_loss = train_finite_sum(NN1, training_data_int, 
                                                               training_data_bound, training_params)

        MC_points = int(1e5) # Number of grid points for comparison with the ground truth
        MSE, L_inf = error_ball(NN1, max(radii), MC_points, display = False)
        
        with torch.no_grad():
            training_error = FD_loss(NN1, training_data_int, training_params)
            test_error = FD_loss(NN1, test_data, training_params)
        
        training_error_history1[j,i] = training_error.mean()
        test_error_history1[j,i] = test_error.mean()
        training_error_history1_max[j,i] = training_error.max().item()
        test_error_history1_max[j,i] = test_error.max().item()
        
        MSE_history1[j,i] = MSE
        L_inf_error_history1[j,i] = L_inf
    
        #epochs =  training_params['epochs']
        #plt.plot(torch.arange(epochs)+1, total_loss)
        #plt.plot(torch.arange(epochs)+1, PDE_loss)
        #plt.plot(torch.arange(epochs)+1, boundary_loss)
        #plt.legend(labels=['Total loss', 'PDE loss', 'BC loss'])
        #plt.show()
        
        #X_axis = 0
        #Y_axis = 1
        #n_grid = 100
        
        #plot_2d_proj_disc(X_axis, Y_axis, NN1, n_grid, n_grid, radii)
        #plot_2d_proj_w(X_axis, Y_axis, NN1, n_grid, radii, training_params,training_data_int)
        
        print('Mean square error:', MSE)
        print('L-infinity error:', L_inf)
# Out:
# 100%|██████████| 500/500 [00:17<00:00, 28.02it/s]
# Mean square error: tensor(0.1714)
# L-infinity error: tensor(2.0992)
# 100%|██████████| 500/500 [00:18<00:00, 26.33it/s]
# Mean square error: tensor(0.1415)
# L-infinity error: tensor(1.9141)
# 100%|██████████| 500/500 [00:18<00:00, 26.97it/s]
# Mean square error: tensor(0.0890)
# L-infinity error: tensor(1.4108)
# 100%|██████████| 500/500 [00:18<00:00, 27.35it/s]
# Mean square error: tensor(0.0669)
# L-infinity error: tensor(1.0817)
# 100%|██████████| 500/500 [00:17<00:00, 28.86it/s]
# Mean square error: tensor(0.0462)
# L-infinity error: tensor(0.9478)
# 100%|██████████| 500/500 [00:17<00:00, 28.84it/s]
# Mean square error: tensor(0.1487)
# L-infinity error: tensor(2.0303)
# 100%|██████████| 500/500 [00:17<00:00, 28.48it/s]
# Mean square error: tensor(0.1198)
# L-infinity error: tensor(1.8227)
# 100%|██████████| 500/500 [00:20<00:00, 24.54it/s]
# Mean square error: tensor(0.0782)
# L-infinity error: tensor(1.2930)
# 100%|██████████| 500/500 [00:21<00:00, 23.73it/s]
# Mean square error: tensor(0.0677)
# L-infinity error: tensor(0.9842)
# 100%|██████████| 500/500 [00:21<00:00, 23.64it/s]
# Mean square error: tensor(0.0491)
# L-infinity error: tensor(0.9270)
# 100%|██████████| 500/500 [00:21<00:00, 23.42it/s]
# Mean square error: tensor(0.1564)
# L-infinity error: tensor(2.0525)
# 100%|██████████| 500/500 [00:21<00:00, 23.10it/s]
# Mean square error: tensor(0.1230)
# L-infinity error: tensor(1.8356)
# 100%|██████████| 500/500 [00:21<00:00, 22.90it/s]
# Mean square error: tensor(0.0778)
# L-infinity error: tensor(1.3276)
# 100%|██████████| 500/500 [00:21<00:00, 23.26it/s]
# Mean square error: tensor(0.0638)
# L-infinity error: tensor(0.9720)
# 100%|██████████| 500/500 [00:20<00:00, 23.87it/s]
# Mean square error: tensor(0.0613)
# L-infinity error: tensor(0.8227)
# 100%|██████████| 500/500 [00:21<00:00, 23.43it/s]
# Mean square error: tensor(0.1384)
# L-infinity error: tensor(2.0352)
# 100%|██████████| 500/500 [00:19<00:00, 25.19it/s]
# Mean square error: tensor(0.1069)
# L-infinity error: tensor(1.8139)
# 100%|██████████| 500/500 [00:18<00:00, 26.75it/s]
# Mean square error: tensor(0.0595)
# L-infinity error: tensor(1.3053)
# 100%|██████████| 500/500 [00:19<00:00, 26.28it/s]
# Mean square error: tensor(0.0417)
# L-infinity error: tensor(0.9148)
# 100%|██████████| 500/500 [00:19<00:00, 26.29it/s]
# Mean square error: tensor(0.0461)
# L-infinity error: tensor(0.8650)
# 100%|██████████| 500/500 [00:18<00:00, 27.38it/s]
# Mean square error: tensor(0.1686)
# L-infinity error: tensor(2.0814)
# 100%|██████████| 500/500 [00:18<00:00, 27.71it/s]
# Mean square error: tensor(0.1407)
# L-infinity error: tensor(1.8811)
# 100%|██████████| 500/500 [00:17<00:00, 28.77it/s]
# Mean square error: tensor(0.1075)
# L-infinity error: tensor(1.4248)
# 100%|██████████| 500/500 [00:17<00:00, 28.54it/s]
# Mean square error: tensor(0.0809)
# L-infinity error: tensor(1.1285)
# 100%|██████████| 500/500 [00:18<00:00, 27.64it/s]
# Mean square error: tensor(0.0528)
# L-infinity error: tensor(0.8184)
# 100%|██████████| 500/500 [00:21<00:00, 23.22it/s]
# Mean square error: tensor(0.1436)
# L-infinity error: tensor(2.0279)
# 100%|██████████| 500/500 [00:22<00:00, 22.64it/s]
# Mean square error: tensor(0.1148)
# L-infinity error: tensor(1.8158)
# 100%|██████████| 500/500 [00:22<00:00, 22.57it/s]
# Mean square error: tensor(0.0718)
# L-infinity error: tensor(1.3744)
# 100%|██████████| 500/500 [00:23<00:00, 20.97it/s]
# Mean square error: tensor(0.0499)
# L-infinity error: tensor(1.0191)
# 100%|██████████| 500/500 [00:24<00:00, 20.73it/s]
# Mean square error: tensor(0.0448)
# L-infinity error: tensor(0.7839)
# 100%|██████████| 500/500 [00:22<00:00, 22.10it/s]
# Mean square error: tensor(0.1582)
# L-infinity error: tensor(2.0594)
# 100%|██████████| 500/500 [00:22<00:00, 22.63it/s]
# Mean square error: tensor(0.1215)
# L-infinity error: tensor(1.8451)
# 100%|██████████| 500/500 [00:20<00:00, 23.86it/s]
# Mean square error: tensor(0.0828)
# L-infinity error: tensor(1.3303)
# 100%|██████████| 500/500 [00:20<00:00, 24.00it/s]
# Mean square error: tensor(0.0714)
# L-infinity error: tensor(1.0432)
# 100%|██████████| 500/500 [00:19<00:00, 25.29it/s]
# Mean square error: tensor(0.0410)
# L-infinity error: tensor(0.7299)
# 100%|██████████| 500/500 [00:19<00:00, 25.50it/s]
# Mean square error: tensor(0.1442)
# L-infinity error: tensor(2.0169)
# 100%|██████████| 500/500 [00:19<00:00, 26.20it/s]
# Mean square error: tensor(0.1245)
# L-infinity error: tensor(1.8183)
# 100%|██████████| 500/500 [00:18<00:00, 27.55it/s]
# Mean square error: tensor(0.1007)
# L-infinity error: tensor(1.3670)
# 100%|██████████| 500/500 [00:18<00:00, 27.71it/s]
# Mean square error: tensor(0.0885)
# L-infinity error: tensor(1.1298)
# 100%|██████████| 500/500 [00:17<00:00, 28.95it/s]
# Mean square error: tensor(0.0721)
# L-infinity error: tensor(1.2248)
# 100%|██████████| 500/500 [00:17<00:00, 28.73it/s]
# Mean square error: tensor(0.1631)
# L-infinity error: tensor(2.0605)
# 100%|██████████| 500/500 [00:17<00:00, 28.55it/s]
# Mean square error: tensor(0.1409)
# L-infinity error: tensor(1.8604)
# 100%|██████████| 500/500 [00:21<00:00, 23.69it/s]
# Mean square error: tensor(0.0968)
# L-infinity error: tensor(1.3383)
# 100%|██████████| 500/500 [00:21<00:00, 23.11it/s]
# Mean square error: tensor(0.0851)
# L-infinity error: tensor(1.0776)
# 100%|██████████| 500/500 [00:22<00:00, 22.42it/s]
# Mean square error: tensor(0.0677)
# L-infinity error: tensor(0.9890)
# 100%|██████████| 500/500 [00:23<00:00, 21.01it/s]
# Mean square error: tensor(0.1592)
# L-infinity error: tensor(2.0563)
# 100%|██████████| 500/500 [00:24<00:00, 20.83it/s]
# Mean square error: tensor(0.1180)
# L-infinity error: tensor(1.8323)
# 100%|██████████| 500/500 [00:23<00:00, 21.74it/s]
# Mean square error: tensor(0.0739)
# L-infinity error: tensor(1.3415)
# 100%|██████████| 500/500 [00:22<00:00, 22.39it/s]
# Mean square error: tensor(0.0568)
# L-infinity error: tensor(1.0368)
# 100%|██████████| 500/500 [00:21<00:00, 23.63it/s]
# Mean square error: tensor(0.0306)
# L-infinity error: tensor(0.8155)

# %%
plt.plot(np.arange(rounds) , training_error_history1.mean(0))
plt.fill_between(np.arange(rounds) , 
                 training_error_history1.mean(0) - training_error_history1.std(0), 
                training_error_history1.mean(0) + training_error_history1.std(0), alpha=0.4)

plt.plot(np.arange(rounds) , test_error_history1.mean(0))
plt.fill_between(np.arange(rounds), 
                test_error_history1.mean(0) - test_error_history1.std(0),
                test_error_history1.mean(0) + test_error_history1.std(0), alpha = 0.4)

plt.legend(labels = ['Training FD loss', 'Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('FD loss')
plt.show()

plt.plot(np.arange(rounds) , training_error_history1_max.mean(0))
plt.fill_between(np.arange(rounds),
                 training_error_history1_max.mean(0) - training_error_history1_max.std(0),
                training_error_history1_max.mean(0) + training_error_history1_max.std(0),
                alpha = .4)

plt.plot(np.arange(rounds) , test_error_history1_max.mean(0))
plt.fill_between(np.arange(rounds),
                test_error_history1_max.mean(0) - test_error_history1_max.std(0),
                test_error_history1_max.mean(0) + test_error_history1_max.std(0),
                alpha = .4)
#plt.ylim(0, test_error_history1_max.max().item()+.1)
plt.legend(labels = ['Training FD loss', 'Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('max of FD loss')
plt.show()

plt.plot(np.arange(rounds), L_inf_error_history1.mean(0))
plt.fill_between(np.arange(rounds),
                L_inf_error_history1.mean(0) - L_inf_error_history1.std(0),
                L_inf_error_history1.mean(0) + L_inf_error_history1.std(0),
                alpha = .4)

plt.ylim(0, L_inf_error_history1.max().item()+0.1)
plt.title('L-inf error w.r.t. ground truth')
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.show()

# %% [markdown]
# # Fixed collocation points II

# %%
MSE_history2 = torch.zeros([n_experiments, rounds])
L_inf_error_history2 = torch.zeros([n_experiments, rounds]) 

training_error_history2 = torch.zeros([n_experiments, rounds])
test_error_history2 = torch.zeros([n_experiments, rounds])

training_error_history2_max = torch.zeros([n_experiments, rounds])
test_error_history2_max = torch.zeros([n_experiments, rounds])


for j in range(n_experiments):
    # We initialise the NN
    NN2 = FCFF_3L([dim,30,30])
    training_params['optimizer'] = optim.SGD(NN2.parameters(), lr = .01, momentum = .2)
    
    ## Here we sample the collocation points and the boundary points.
    training_data_int = domain.rand_int_points(0., 400)
    training_data_bound = domain.rand_bound_points(80)
    
    training_params['epochs'] = 500
    training_params['batch_size'] = 50

    
    for i in range(rounds):
    
        training_params['alpha'] = alpha_list[i]
        training_params['delta'] = delta_list[i]
        
        total_loss, PDE_loss, boundary_loss = train_finite_sum(NN2, training_data_int, 
                                                               training_data_bound, training_params)

        MC_points = int(1e5) # Number of grid points for comparison with the ground truth
        MSE, L_inf = error_ball(NN2, max(radii), MC_points, display = False)
        
        with torch.no_grad():
            training_error = FD_loss(NN2, training_data_int, training_params)
            test_error = FD_loss(NN2, test_data, training_params)
        
        training_error_history2[j,i] = training_error.mean()
        test_error_history2[j,i] = test_error.mean()
        training_error_history2_max[j,i] = training_error.max().item()
        test_error_history2_max[j,i] = test_error.max().item()
        
        MSE_history2[j,i] = MSE
        L_inf_error_history2[j,i] = L_inf
    
        
        print('Mean square error:', MSE)
        print('L-infinity error:', L_inf)
# Out:
# 100%|██████████| 500/500 [00:39<00:00, 12.58it/s]
# Mean square error: tensor(0.1229)
# L-infinity error: tensor(1.9842)
# 100%|██████████| 500/500 [00:37<00:00, 13.42it/s]
# Mean square error: tensor(0.0866)
# L-infinity error: tensor(1.7417)
# 100%|██████████| 500/500 [00:35<00:00, 13.91it/s]
# Mean square error: tensor(0.0374)
# L-infinity error: tensor(1.1566)
# 100%|██████████| 500/500 [00:35<00:00, 14.25it/s]
# Mean square error: tensor(0.0245)
# L-infinity error: tensor(0.8029)
# 100%|██████████| 500/500 [00:36<00:00, 13.65it/s]
# Mean square error: tensor(0.0214)
# L-infinity error: tensor(0.7249)
# 100%|██████████| 500/500 [00:41<00:00, 11.99it/s]
# Mean square error: tensor(0.1232)
# L-infinity error: tensor(1.9772)
# 100%|██████████| 500/500 [00:43<00:00, 11.49it/s]
# Mean square error: tensor(0.0909)
# L-infinity error: tensor(1.7507)
# 100%|██████████| 500/500 [00:42<00:00, 11.65it/s]
# Mean square error: tensor(0.0453)
# L-infinity error: tensor(1.2003)
# 100%|██████████| 500/500 [00:40<00:00, 12.50it/s]
# Mean square error: tensor(0.0270)
# L-infinity error: tensor(0.8492)
# 100%|██████████| 500/500 [00:38<00:00, 13.02it/s]
# Mean square error: tensor(0.0248)
# L-infinity error: tensor(0.6848)
# 100%|██████████| 500/500 [00:37<00:00, 13.27it/s]
# Mean square error: tensor(0.1195)
# L-infinity error: tensor(1.9861)
# 100%|██████████| 500/500 [00:35<00:00, 13.94it/s]
# Mean square error: tensor(0.0865)
# L-infinity error: tensor(1.7552)
# 100%|██████████| 500/500 [00:35<00:00, 14.15it/s]
# Mean square error: tensor(0.0363)
# L-infinity error: tensor(1.1704)
# 100%|██████████| 500/500 [00:36<00:00, 13.82it/s]
# Mean square error: tensor(0.0216)
# L-infinity error: tensor(0.8120)
# 100%|██████████| 500/500 [00:40<00:00, 12.24it/s]
# Mean square error: tensor(0.0190)
# L-infinity error: tensor(0.6320)
# 100%|██████████| 500/500 [00:42<00:00, 11.79it/s]
# Mean square error: tensor(0.1228)
# L-infinity error: tensor(1.9728)
# 100%|██████████| 500/500 [00:42<00:00, 11.87it/s]
# Mean square error: tensor(0.0781)
# L-infinity error: tensor(1.7193)
# 100%|██████████| 500/500 [00:39<00:00, 12.57it/s]
# Mean square error: tensor(0.0354)
# L-infinity error: tensor(1.1318)
# 100%|██████████| 500/500 [00:38<00:00, 13.12it/s]
# Mean square error: tensor(0.0273)
# L-infinity error: tensor(0.7995)
# 100%|██████████| 500/500 [00:37<00:00, 13.32it/s]
# Mean square error: tensor(0.0247)
# L-infinity error: tensor(0.6620)
# 100%|██████████| 500/500 [00:36<00:00, 13.52it/s]
# Mean square error: tensor(0.1204)
# L-infinity error: tensor(1.9770)
# 100%|██████████| 500/500 [00:36<00:00, 13.71it/s]
# Mean square error: tensor(0.0842)
# L-infinity error: tensor(1.7397)
# 100%|██████████| 500/500 [00:36<00:00, 13.57it/s]
# Mean square error: tensor(0.0387)
# L-infinity error: tensor(1.1671)
# 100%|██████████| 500/500 [00:42<00:00, 11.89it/s]
# Mean square error: tensor(0.0239)
# L-infinity error: tensor(0.8242)
# 100%|██████████| 500/500 [00:43<00:00, 11.47it/s]
# Mean square error: tensor(0.0322)
# L-infinity error: tensor(0.6824)
# 100%|██████████| 500/500 [00:43<00:00, 11.49it/s]
# Mean square error: tensor(0.1273)
# L-infinity error: tensor(1.9942)
# 100%|██████████| 500/500 [00:40<00:00, 12.29it/s]
# Mean square error: tensor(0.0948)
# L-infinity error: tensor(1.7682)
# 100%|██████████| 500/500 [00:38<00:00, 12.92it/s]
# Mean square error: tensor(0.0433)
# L-infinity error: tensor(1.1578)
# 100%|██████████| 500/500 [00:38<00:00, 12.90it/s]
# Mean square error: tensor(0.0340)
# L-infinity error: tensor(0.8918)
# 100%|██████████| 500/500 [00:37<00:00, 13.36it/s]
# Mean square error: tensor(0.0309)
# L-infinity error: tensor(0.7458)
# 100%|██████████| 500/500 [00:36<00:00, 13.61it/s]
# Mean square error: tensor(0.1199)
# L-infinity error: tensor(1.9714)
# 100%|██████████| 500/500 [00:37<00:00, 13.21it/s]
# Mean square error: tensor(0.0793)
# L-infinity error: tensor(1.7246)
# 100%|██████████| 500/500 [00:44<00:00, 11.33it/s]
# Mean square error: tensor(0.0385)
# L-infinity error: tensor(1.1530)
# 100%|██████████| 500/500 [00:45<00:00, 10.91it/s]
# Mean square error: tensor(0.0235)
# L-infinity error: tensor(0.7725)
# 100%|██████████| 500/500 [00:43<00:00, 11.49it/s]
# Mean square error: tensor(0.0212)
# L-infinity error: tensor(0.6002)
# 100%|██████████| 500/500 [00:41<00:00, 11.93it/s]
# Mean square error: tensor(0.1372)
# L-infinity error: tensor(2.0177)
# 100%|██████████| 500/500 [00:39<00:00, 12.59it/s]
# Mean square error: tensor(0.1026)
# L-infinity error: tensor(1.7898)
# 100%|██████████| 500/500 [00:38<00:00, 12.88it/s]
# Mean square error: tensor(0.0574)
# L-infinity error: tensor(1.2131)
# 100%|██████████| 500/500 [00:36<00:00, 13.67it/s]
# Mean square error: tensor(0.0390)
# L-infinity error: tensor(0.8507)
# 100%|██████████| 500/500 [00:34<00:00, 14.53it/s]
# Mean square error: tensor(0.0273)
# L-infinity error: tensor(0.6718)
# 100%|██████████| 500/500 [00:39<00:00, 12.77it/s]
# Mean square error: tensor(0.1303)
# L-infinity error: tensor(1.9860)
# 100%|██████████| 500/500 [00:43<00:00, 11.37it/s]
# Mean square error: tensor(0.0984)
# L-infinity error: tensor(1.7536)
# 100%|██████████| 500/500 [00:46<00:00, 10.65it/s]
# Mean square error: tensor(0.0494)
# L-infinity error: tensor(1.2090)
# 100%|██████████| 500/500 [00:44<00:00, 11.19it/s]
# Mean square error: tensor(0.0305)
# L-infinity error: tensor(0.8810)
# 100%|██████████| 500/500 [00:41<00:00, 12.00it/s]
# Mean square error: tensor(0.0345)
# L-infinity error: tensor(0.7772)
# 100%|██████████| 500/500 [00:39<00:00, 12.75it/s]
# Mean square error: tensor(0.1126)
# L-infinity error: tensor(1.9618)
# 100%|██████████| 500/500 [00:38<00:00, 12.95it/s]
# Mean square error: tensor(0.0798)
# L-infinity error: tensor(1.7294)
# 100%|██████████| 500/500 [00:36<00:00, 13.72it/s]
# Mean square error: tensor(0.0315)
# L-infinity error: tensor(1.1703)
# 100%|██████████| 500/500 [00:35<00:00, 14.26it/s]
# Mean square error: tensor(0.0201)
# L-infinity error: tensor(0.8129)
# 100%|██████████| 500/500 [00:41<00:00, 12.18it/s]
# Mean square error: tensor(0.0220)
# L-infinity error: tensor(0.6455)

# %%
plt.plot(np.arange(rounds) , training_error_history2.mean(0))
plt.fill_between(np.arange(rounds) , 
                 training_error_history2.mean(0) - training_error_history2.std(0), 
                training_error_history2.mean(0) + training_error_history2.std(0), alpha=0.4)

plt.plot(np.arange(rounds) , test_error_history2.mean(0))
plt.fill_between(np.arange(rounds), 
                test_error_history2.mean(0) - test_error_history2.std(0),
                test_error_history2.mean(0) + test_error_history2.std(0), alpha = 0.4)

plt.legend(labels = ['Training FD loss', 'Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('FD loss')
plt.show()

plt.plot(np.arange(rounds) , training_error_history2_max.mean(0))
plt.fill_between(np.arange(rounds),
                 training_error_history2_max.mean(0) - training_error_history2_max.std(0),
                training_error_history2_max.mean(0) + training_error_history2_max.std(0),
                alpha = .4)

plt.plot(np.arange(rounds) , test_error_history2_max.mean(0))
plt.fill_between(np.arange(rounds),
                test_error_history2_max.mean(0) - test_error_history2_max.std(0),
                test_error_history2_max.mean(0) + test_error_history2_max.std(0),
                alpha = .4)
#plt.ylim(0, test_error_history1_max.max().item()+.1)
plt.legend(labels = ['Training FD loss', 'Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('max of FD loss')
plt.show()

plt.plot(np.arange(rounds), L_inf_error_history2.mean(0))
plt.fill_between(np.arange(rounds),
                L_inf_error_history2.mean(0) - L_inf_error_history2.std(0),
                L_inf_error_history2.mean(0) + L_inf_error_history2.std(0),
                alpha = .4)

plt.ylim(0, L_inf_error_history2.max().item()+0.1)
plt.title('L-inf error w.r.t. ground truth')
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.show()

# %% [markdown]
# # Re-sampling

# %%
MSE_history3 = torch.zeros([n_experiments, rounds])
L_inf_error_history3 = torch.zeros([n_experiments, rounds]) 

training_error_history3 = torch.zeros([n_experiments, rounds])
test_error_history3 = torch.zeros([n_experiments, rounds])

test_error_history3_max = torch.zeros([n_experiments, rounds])

from Training.training import train

training_params['n_coloc_points'] = 300
training_params['n_boundary_points'] = 50
n_ite = 2500
training_params['num_iterations'] = n_ite

for j in range(n_experiments):
    # We initialise the NN
    NN3 = FCFF_3L([dim,30,30])
    training_params['optimizer'] = optim.SGD(NN3.parameters(), lr = .01, momentum = .2)

    
    for i in range(rounds):
    
        training_params['alpha'] = alpha_list[i]
        training_params['delta'] = delta_list[i]

        total_loss, PDE_loss, boundary_loss = train(NN3, domain, training_params)

        MC_points = int(1e5) # Number of grid points for comparison with the ground truth
        MSE, L_inf = error_ball(NN3, max(radii), MC_points, display = False)
        
        with torch.no_grad():
            #training_error = FD_loss(NN2, training_data_int, training_params)
            test_error = FD_loss(NN3, test_data, training_params)
        
        training_error_history3[j,i] = PDE_loss[-1]
        test_error_history3[j,i] = test_error.mean()
        test_error_history3_max[j,i] = test_error.max().item()
        
        MSE_history3[j,i] = MSE
        L_inf_error_history3[j,i] = L_inf
        
        print('Mean square error:', MSE)
        print('L-infinity error:', L_inf)
# Out:
# 100%|██████████| 2500/2500 [00:23<00:00, 105.85it/s]
# Mean square error: tensor(0.1170)
# L-infinity error: tensor(1.9853)
# 100%|██████████| 2500/2500 [00:25<00:00, 97.05it/s]
# Mean square error: tensor(0.0750)
# L-infinity error: tensor(1.7214)
# 100%|██████████| 2500/2500 [00:27<00:00, 92.26it/s]
# Mean square error: tensor(0.0229)
# L-infinity error: tensor(1.0648)
# 100%|██████████| 2500/2500 [00:27<00:00, 90.91it/s]
# Mean square error: tensor(0.0125)
# L-infinity error: tensor(0.7117)
# 100%|██████████| 2500/2500 [00:25<00:00, 96.46it/s]
# Mean square error: tensor(0.0052)
# L-infinity error: tensor(0.4616)
# 100%|██████████| 2500/2500 [00:25<00:00, 99.64it/s]
# Mean square error: tensor(0.1130)
# L-infinity error: tensor(1.9740)
# 100%|██████████| 2500/2500 [00:24<00:00, 100.62it/s]
# Mean square error: tensor(0.0711)
# L-infinity error: tensor(1.7090)
# 100%|██████████| 2500/2500 [00:25<00:00, 99.90it/s]
# Mean square error: tensor(0.0200)
# L-infinity error: tensor(1.0588)
# 100%|██████████| 2500/2500 [00:24<00:00, 100.89it/s]
# Mean square error: tensor(0.0089)
# L-infinity error: tensor(0.6982)
# 100%|██████████| 2500/2500 [00:23<00:00, 107.57it/s]
# Mean square error: tensor(0.0057)
# L-infinity error: tensor(0.4511)
# 100%|██████████| 2500/2500 [00:22<00:00, 110.36it/s]
# Mean square error: tensor(0.1118)
# L-infinity error: tensor(1.9771)
# 100%|██████████| 2500/2500 [00:22<00:00, 111.20it/s]
# Mean square error: tensor(0.0689)
# L-infinity error: tensor(1.7087)
# 100%|██████████| 2500/2500 [00:22<00:00, 111.19it/s]
# Mean square error: tensor(0.0198)
# L-infinity error: tensor(1.0585)
# 100%|██████████| 2500/2500 [00:22<00:00, 108.88it/s]
# Mean square error: tensor(0.0091)
# L-infinity error: tensor(0.6932)
# 100%|██████████| 2500/2500 [00:24<00:00, 102.41it/s]
# Mean square error: tensor(0.0047)
# L-infinity error: tensor(0.4473)
# 100%|██████████| 2500/2500 [00:25<00:00, 98.62it/s]
# Mean square error: tensor(0.1165)
# L-infinity error: tensor(1.9845)
# 100%|██████████| 2500/2500 [00:27<00:00, 92.25it/s]
# Mean square error: tensor(0.0712)
# L-infinity error: tensor(1.7150)
# 100%|██████████| 2500/2500 [00:27<00:00, 91.33it/s]
# Mean square error: tensor(0.0214)
# L-infinity error: tensor(1.0640)
# 100%|██████████| 2500/2500 [00:27<00:00, 92.10it/s]
# Mean square error: tensor(0.0094)
# L-infinity error: tensor(0.6939)
# 100%|██████████| 2500/2500 [00:26<00:00, 96.04it/s]
# Mean square error: tensor(0.0055)
# L-infinity error: tensor(0.4691)
# 100%|██████████| 2500/2500 [00:25<00:00, 96.77it/s]
# Mean square error: tensor(0.1123)
# L-infinity error: tensor(1.9700)
# 100%|██████████| 2500/2500 [00:24<00:00, 101.13it/s]
# Mean square error: tensor(0.0724)
# L-infinity error: tensor(1.7089)
# 100%|██████████| 2500/2500 [00:24<00:00, 101.53it/s]
# Mean square error: tensor(0.0201)
# L-infinity error: tensor(1.0567)
# 100%|██████████| 2500/2500 [00:23<00:00, 104.66it/s]
# Mean square error: tensor(0.0094)
# L-infinity error: tensor(0.6957)
# 100%|██████████| 2500/2500 [00:24<00:00, 102.95it/s]
# Mean square error: tensor(0.0056)
# L-infinity error: tensor(0.4508)
# 100%|██████████| 2500/2500 [00:21<00:00, 114.18it/s]
# Mean square error: tensor(0.1149)
# L-infinity error: tensor(1.9787)
# 100%|██████████| 2500/2500 [00:22<00:00, 112.41it/s]
# Mean square error: tensor(0.0718)
# L-infinity error: tensor(1.7124)
# 100%|██████████| 2500/2500 [00:23<00:00, 106.48it/s]
# Mean square error: tensor(0.0214)
# L-infinity error: tensor(1.0626)
# 100%|██████████| 2500/2500 [00:23<00:00, 104.20it/s]
# Mean square error: tensor(0.0094)
# L-infinity error: tensor(0.6981)
# 100%|██████████| 2500/2500 [00:25<00:00, 97.27it/s]
# Mean square error: tensor(0.0061)
# L-infinity error: tensor(0.4584)
# 100%|██████████| 2500/2500 [00:26<00:00, 94.61it/s]
# Mean square error: tensor(0.1130)
# L-infinity error: tensor(1.9795)
# 100%|██████████| 2500/2500 [00:26<00:00, 94.34it/s]
# Mean square error: tensor(0.0716)
# L-infinity error: tensor(1.7128)
# 100%|██████████| 2500/2500 [00:25<00:00, 97.48it/s]
# Mean square error: tensor(0.0215)
# L-infinity error: tensor(1.0655)
# 100%|██████████| 2500/2500 [00:24<00:00, 101.37it/s]
# Mean square error: tensor(0.0093)
# L-infinity error: tensor(0.6996)
# 100%|██████████| 2500/2500 [00:24<00:00, 102.56it/s]
# Mean square error: tensor(0.0052)
# L-infinity error: tensor(0.4580)
# 100%|██████████| 2500/2500 [00:24<00:00, 102.67it/s]
# Mean square error: tensor(0.1130)
# L-infinity error: tensor(1.9779)
# 100%|██████████| 2500/2500 [00:24<00:00, 103.89it/s]
# Mean square error: tensor(0.0704)
# L-infinity error: tensor(1.7134)
# 100%|██████████| 2500/2500 [00:24<00:00, 103.41it/s]
# Mean square error: tensor(0.0188)
# L-infinity error: tensor(1.0522)
# 100%|██████████| 2500/2500 [00:23<00:00, 105.69it/s]
# Mean square error: tensor(0.0082)
# L-infinity error: tensor(0.6903)
# 100%|██████████| 2500/2500 [00:22<00:00, 111.66it/s]
# Mean square error: tensor(0.0043)
# L-infinity error: tensor(0.4503)
# 100%|██████████| 2500/2500 [00:22<00:00, 110.27it/s]
# Mean square error: tensor(0.1106)
# L-infinity error: tensor(1.9763)
# 100%|██████████| 2500/2500 [00:22<00:00, 108.70it/s]
# Mean square error: tensor(0.0691)
# L-infinity error: tensor(1.7075)
# 100%|██████████| 2500/2500 [00:23<00:00, 107.18it/s]
# Mean square error: tensor(0.0196)
# L-infinity error: tensor(1.0558)
# 100%|██████████| 2500/2500 [00:24<00:00, 103.20it/s]
# Mean square error: tensor(0.0081)
# L-infinity error: tensor(0.6911)
# 100%|██████████| 2500/2500 [00:26<00:00, 94.15it/s]
# Mean square error: tensor(0.0043)
# L-infinity error: tensor(0.4505)
# 100%|██████████| 2500/2500 [00:26<00:00, 96.08it/s]
# Mean square error: tensor(0.1138)
# L-infinity error: tensor(1.9786)
# 100%|██████████| 2500/2500 [00:25<00:00, 97.56it/s]
# Mean square error: tensor(0.0717)
# L-infinity error: tensor(1.7106)
# 100%|██████████| 2500/2500 [00:23<00:00, 104.21it/s]
# Mean square error: tensor(0.0227)
# L-infinity error: tensor(1.0656)
# 100%|██████████| 2500/2500 [00:23<00:00, 106.67it/s]
# Mean square error: tensor(0.0109)
# L-infinity error: tensor(0.7043)
# 100%|██████████| 2500/2500 [00:23<00:00, 108.01it/s]
# Mean square error: tensor(0.0056)
# L-infinity error: tensor(0.4615)

# %%
plt.plot(np.arange(rounds) , training_error_history3.mean(0))
plt.fill_between(np.arange(rounds) , 
                 training_error_history3.mean(0) - training_error_history3.std(0), 
                training_error_history3.mean(0) + training_error_history3.std(0), alpha=0.4)

plt.plot(np.arange(rounds) , test_error_history3.mean(0))
plt.fill_between(np.arange(rounds), 
                test_error_history3.mean(0) - test_error_history3.std(0),
                test_error_history3.mean(0) + test_error_history3.std(0), alpha = 0.4)

plt.legend(labels = ['Training FD loss', 'Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('FD loss')
plt.show()

plt.plot(np.arange(rounds) , test_error_history3_max.mean(0))
plt.fill_between(np.arange(rounds),
                test_error_history3_max.mean(0) - test_error_history3_max.std(0),
                test_error_history3_max.mean(0) + test_error_history3_max.std(0),
                alpha = .4)
plt.legend(labels = ['Test FD loss'])
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('max of FD loss')
plt.show()

plt.plot(np.arange(rounds), L_inf_error_history3.mean(0))
plt.fill_between(np.arange(rounds),
                L_inf_error_history3.mean(0) - L_inf_error_history3.std(0),
                L_inf_error_history3.mean(0) + L_inf_error_history3.std(0),
                alpha = .4)

plt.ylim(0, L_inf_error_history3.max().item()+0.1)
plt.xticks([i for i in range(rounds)], [i+1 for i in range(rounds)])
plt.title('L-inf error w.r.t. ground truth')
plt.show()

# %%
plt.plot(np.arange(rounds) , test_error_history1.mean(0))
plt.plot(np.arange(rounds) , test_error_history2.mean(0))
plt.plot(np.arange(rounds) , test_error_history3.mean(0))

plt.fill_between(np.arange(rounds), 
                test_error_history1.mean(0) - test_error_history1.std(0),
                test_error_history1.mean(0) + test_error_history1.std(0), alpha = 0.4)

plt.fill_between(np.arange(rounds), 
                test_error_history2.mean(0) - test_error_history2.std(0),
                test_error_history2.mean(0) + test_error_history2.std(0), alpha = 0.4)

plt.fill_between(np.arange(rounds), 
                test_error_history3.mean(0) - test_error_history3.std(0),
                test_error_history3.mean(0) + test_error_history3.std(0), alpha = 0.4)

plt.legend(labels = ['$N_0 = 200$', '$N_0 = 400$', 'Re-sampling'], fontsize=14)
plt.xticks([i for i in range(rounds)], [ delta_list[i] for i in range(rounds)])

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Mean square F.D. residual', fontsize = 'xx-large')
plt.show()


plt.plot(np.arange(rounds) , test_error_history1_max.mean(0))
plt.plot(np.arange(rounds) , test_error_history2_max.mean(0))
plt.plot(np.arange(rounds) , test_error_history3_max.mean(0))

plt.fill_between(np.arange(rounds),
                test_error_history1_max.mean(0) - test_error_history1_max.std(0),
                test_error_history1_max.mean(0) + test_error_history1_max.std(0),
                alpha = .4)

plt.fill_between(np.arange(rounds),
                test_error_history2_max.mean(0) - test_error_history2_max.std(0),
                test_error_history2_max.mean(0) + test_error_history2_max.std(0),
                alpha = .4)

plt.fill_between(np.arange(rounds),
                test_error_history3_max.mean(0) - test_error_history3_max.std(0),
                test_error_history3_max.mean(0) + test_error_history3_max.std(0),
                alpha = .4)

#plt.legend(labels = ['$N_0 = 80$', '$N_0 = 160$', 'Re-sampling'], fontsize=14)
plt.xticks([i for i in range(rounds)], [ delta_list[i] for i in range(rounds)])

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('Maximum of the F.D. residual', fontsize = 'xx-large')
plt.show()


plt.plot(np.arange(rounds), MSE_history1.log().mean(0))
plt.plot(np.arange(rounds), MSE_history2.log().mean(0))
plt.plot(np.arange(rounds), MSE_history3.log().mean(0))

plt.fill_between(np.arange(rounds),
                MSE_history1.log().mean(0) - MSE_history1.log10().std(0),
                MSE_history1.log().mean(0) + MSE_history1.log10().std(0),
                alpha = .4)

plt.fill_between(np.arange(rounds),
                MSE_history2.log().mean(0) - MSE_history2.log10().std(0),
                MSE_history2.log().mean(0) + MSE_history2.log10().std(0),
                alpha = .4)

plt.fill_between(np.arange(rounds),
                MSE_history3.log().mean(0) - MSE_history3.log10().std(0),
                MSE_history3.log().mean(0) + MSE_history3.log10().std(0),
                alpha = .4)

plt.legend(labels = ['$N_0 = 200$', '$N_0 = 400$', 'Re-sampling'], fontsize=14)
plt.xticks([i for i in range(rounds)], [ delta_list[i] for i in range(rounds)])

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('$\log_{10} (MSE)$', fontsize = 'xx-large')
plt.show()


plt.plot(np.arange(rounds), L_inf_error_history1.mean(0).log10())
plt.fill_between(np.arange(rounds),
                (L_inf_error_history1.mean(0) - L_inf_error_history1.std(0)).log10(),
                (L_inf_error_history1.mean(0) + L_inf_error_history1.std(0)).log10(),
                alpha = .4)

plt.plot(np.arange(rounds), L_inf_error_history2.mean(0).log10())
plt.fill_between(np.arange(rounds),
                (L_inf_error_history2.mean(0) - L_inf_error_history2.std(0)).log10(),
                (L_inf_error_history2.mean(0) + L_inf_error_history2.std(0)).log10(),
                alpha = .4)

plt.plot(np.arange(rounds), L_inf_error_history3.mean(0).log10())
plt.fill_between(np.arange(rounds),
                (L_inf_error_history3.mean(0) - L_inf_error_history3.std(0)).log10(),
                (L_inf_error_history3.mean(0) + L_inf_error_history3.std(0)).log10(),
                alpha = .4)

#plt.legend(labels = ['$N_0 = 80$', '$N_0 = 160$', 'Re-sampling'], fontsize=14)
plt.xticks([i for i in range(rounds)], [ delta_list[i] for i in range(rounds)])

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('$\log_{10} (E_{\infty})$', fontsize = 'xx-large')
plt.show()
# Out:
# <>:78: SyntaxWarning: invalid escape sequence '\l'
# <>:105: SyntaxWarning: invalid escape sequence '\l'
# <>:78: SyntaxWarning: invalid escape sequence '\l'
# <>:105: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\usuario\AppData\Local\Temp\ipykernel_21164\3603678447.py:78: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('$\log_{10} (MSE)$', fontsize = 'xx-large')
# C:\Users\usuario\AppData\Local\Temp\ipykernel_21164\3603678447.py:105: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('$\log_{10} (E_{\infty})$', fontsize = 'xx-large')
